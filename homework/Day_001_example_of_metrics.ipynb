# %% [markdown]
# # 統計指標實作範例
# ## 常見於迴歸問題的評估指標
# * Mean Absolute Error (MAE)
# * Mean Squared Error (MSE)
#
# ## 常見於分類問題的指標
# * Binary Cross Entropy (CE)
#
# ##### 後面的課程還會有更詳細的說明

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 11.005

# %% [markdown]
# ## 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# * 你選的這組資料為何重要
#     - 我選擇的是[NOAA ICOADS](https://www.kaggle.com/noaa/noaa-icoads)這個資料集。由於研究所期間主修海洋學，看到這個資料集備感熟悉。裡頭包含了風與浪的觀測資料，雖然大氣與海洋的交互作用十分複雜，但或許能用這個資料集，訓練出一個還不錯的模型，可以用來預測某個地點的波浪資訊。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#     - 根據這個資料集的說明，資料來自多個國家的海事單位（海軍、海巡、海洋保護）的船艦或浮球，也包括民間船隻提供的觀測記錄。
#
# 3. 蒐集而來的資料型態為何
#     - 文字或數字組成的多欄位資料。
#
# 4. 這組資料想解決的問題如何評估
#     - 初步的想法（參考該資料集上的一個現有的Kernel）是以相關資料來預測波高，預測值與觀測值之間的誤差，可以用本次作業的第三題：MSE來做評估。

# %% [markdown]
# ## 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     - 車隊裡的每個成員，每月載客次數愈多，就能提升整體業績愈多。而成員的載客次數，除了系統根據叫車地點指派臨近車輛外，或許也與成員及其車輛的條件有關。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     - 車隊成員資料：性別、年齡、從業年數、主要載客區域、每月載客次數、到達派車地點平均時間、顧客評點平均得分。
#     - 車輛資料：廠牌、車型、車齡
#
# 3. 蒐集而來的資料型態為何
#     - 文字或數字組成的多欄位資料。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     - 訓練一個迴歸模型，用上述資料推算每月載客次數。訓練過程中，觀寫評估指標（MAE或MSE的變化）

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
#
# 作業3：計算Mean squared error的函式
#
def mean_square_error(y: np.ndarray, yp: np.ndarray):
    """
    計算 Mean Square Error (MSE)
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    return sum((y - yp) ** 2) / len(y)

mse = mean_square_error(y, y_hat)
print("The Mean squared error is %.3f" % (mse))
# Out:
# The Mean squared error is 205.219
